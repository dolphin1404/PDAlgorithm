# %% [markdown]
# <a href="https://colab.research.google.com/github/wootaehyeon/PDAlgorithm/blob/main/intro_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import numpy as np

# %%
tensor_a = torch.tensor([1,2,3,4])
tensor_b = torch.tensor([5,6,7,8])

# %%
#Addition
tensor_a +tensor_b
# Out:
# tensor([ 6,  8, 10, 12])

# %%
#Addition Longhand
torch.add(tensor_a,tensor_b)
# Out:
# tensor([ 6,  8, 10, 12])

# %%
#subtraction
tensor_b - tensor_a
# Out:
# tensor([4, 4, 4, 4])

# %%
#subfuntion
torch.sub(tensor_a,tensor_b)
# Out:
# tensor([-4, -4, -4, -4])

# %% [markdown]
# Multiplication
